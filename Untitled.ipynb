# %%
import pandas as pd
import os

# %%
df = pd.read_csv("df_main.csv")
df
# Out:
#       Unnamed: 0      category                beverage  \
# 0              0    White Wine                Sancerre
# 1              1    White Wine                Sancerre
# 2              2    White Wine  Gewürztraminer, Alsace
# 3              3  Dessert Wine               Sauternes
# 4              4  Dessert Wine                 Banyuls
# ...          ...           ...                     ...
# 7780        7780    White Wine          Grenache Blanc
# 7781        7781    White Wine          Grenache Blanc
# 7782        7782      Red Wine              Beaujolais
# 7783        7783      Red Wine      Cabernet Sauvignon
# 7784        7784      Red Wine              Pinot Noir
#
#                              food  rating  \
# 0                   Chevre Cheese     5.0
# 1                     Goat Cheese     5.0
# 2                 Muenster Cheese     5.0
# 3                Roquefort Cheese     5.0
# 4                  Dark Chocolate     5.0
# ...                           ...     ...
# ...

# %%
red_df = df[df["category"] == "Red Wine"]
cab_df = red_df[red_df["beverage"]=="Cabernet Sauvignon"]
cab_df
# Out:
#       Unnamed: 0  category            beverage                food  rating  \
# 26            26  Red Wine  Cabernet Sauvignon               Steak     5.0
# 39            39  Red Wine  Cabernet Sauvignon       Ribeye Steak      5.0
# 112          112  Red Wine  Cabernet Sauvignon      Cheddar Cheese     4.5
# 284          284  Red Wine  Cabernet Sauvignon          Hamburgers     4.5
# 307          307  Red Wine  Cabernet Sauvignon          Lamb Chops     4.5
# ...          ...       ...                 ...                 ...     ...
# 7694        7694  Red Wine  Cabernet Sauvignon         Lamb Kebabs     3.5
# 7731        7731  Red Wine  Cabernet Sauvignon             Kidneys     3.5
# 7767        7767  Red Wine  Cabernet Sauvignon         Blue Cheese     1.5
# 7768        7768  Red Wine  Cabernet Sauvignon  Danish Blue Cheese     1.5
# 7783        7783  Red Wine  Cabernet Sauvignon      Dark Chocolate     2.0
#
#                                              recipeName  \
# ...

# %%
for e in df
# Out:
# Ratatouille            1
# Blue Cheese            1
# Grilled Eggplant       1
# Steak and Mushrooms    1
# Veal Chops             1
#                       ..
# Turkey Roasted         1
# Shark                  1
# Danish Blue Cheese     1
# Lamb Kebabs            2
# Kidneys                2
# Name: Food, Length: 139, dtype: int64

# %%
pair_df["Food"].unique()
# Out:
# array(['Steak', 'Ribeye Steak ', 'Cheddar Cheese', 'Hamburgers',
#        'Lamb Chops', 'Roasted Lamb', 'Lamb Shanks', 'Meatloaf', 'Mint',
#        'Black Pepper', 'Squab', 'Squab Roasted',
#        'Steak with Black Pepper', 'Steak Filet Mignon', 'Grilled Steak',
#        'Steak Rib Eye', 'NY Strip Steak', 'BBQ Ribs', 'Roast Beef',
#        'Beef Stew', 'Brie Cheese', 'Camembert Cheese', 'Gouda Cheese',
#        'Monterey Jack Cheese', 'Chicken', 'Chicken with Paprika',
#        'Chicken Tikka Masala', 'Duck', 'Duck Confit', 'Grilled Dishes',
#        'Grilled Hamburgers', 'Herbed Dishes', 'Lamb', 'Lamb Burgers',
#        'Grilled Lamb', 'Roasted Leg of Lamb', 'Lamb Stew', 'Oregano',
#        'Quail', 'Rosemary', 'Tête de Veau', 'Southwestern Cuisine',
#        'Steak and Mushrooms', 'Steak Porterhouse', 'Steak Rare',
#        'Steak Medium Rare', 'Steak Sirloin', 'Thyme', 'Grilled Tuna',
#        'Turkey', 'Turkey Roasted', 'Veal', 'Veal Chops', 'Veal Roasted',
# ...
