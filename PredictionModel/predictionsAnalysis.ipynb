# %%
import pandas as pd

# %%
df = pd.read_csv('testPredictionsFull.csv')
df = df.drop(columns = 'Unnamed: 0')
df
# Out:
#                                          name  \
# 0                    chicken breasts lombardi
# 1      low fat burgundy beef   vegetable stew
# 2                   lou s fabulous bruschetta
# 3          black bean  corn  and tomato salad
# 4                    cabbage and sausage soup
# ...                                       ...
# 76733                      garlic prawn pasta
# 76734         slow cooker soy braised chicken
# 76735            thanksgiving turkey meatloaf
# 76736         garlic and herb mashed potatoes
# 76737       mini buffalo chicken cheesesteaks
#
#                                              ingredients  \
# 0      fresh mushrooms  butter  boneless skinless chi...
# 1      beef eye round  vegetable oil  dried thyme lea...
# 2      french baguette  butter  garlic powder  ricott...
# 3      fresh lemon juice  olive oil  black beans  fre...
# 4      olive oil  italian sausage  white onions  garl...
# ...                                                  ...
# 76733  prawns  spaghetti  butter  olive oil  garlic c...
# 76734  onions  garlic cloves  apple cider vinegar  so...
# 76735  seasoned stuffing mix  milk  egg  onion  celer...
# 76736  yukon gold potatoes  cream cheese  butter  sou...
# 76737  olive oil  green bell pepper  yellow onion  sa...
#
#                                                 Predicts  calories  fat (pdv)  \
# 0                   ['chardonnay' 'pinot noir' 'merlot']     627.7       38.0
# 1          ['touriga nacional' 'tempranillo' 'nebbiolo']     280.1        9.0
# 2              ['chardonnay' 'champagne' 'riesling dry']     221.5       10.0
# 3        ['riesling off-dry' 'garganega' 'riesling dry']     407.8       23.0
# 4      ['sangiovese' 'riesling off-dry' 'cabernet fra...     586.1       59.0
# ...                                                  ...       ...        ...
# 76733  ['chardonnay' 'chenin blanc off-dry' 'riesling...     598.1       27.0
# 76734      ['riesling off-dry' 'tempranillo' 'carignan']     655.4       45.0
# 76735   ['riesling off-dry' 'viognier' 'gewurztraminer']     342.3       24.0
# 76736       ['gewurztraminer' 'pinot noir' 'chardonnay']     390.8       37.0
# 76737              ['malbec' 'sangiovese' 'tempranillo']     407.9       34.0
#
#        sugar (pdv)  sodium (pdv)  protein (pdv)  saturated fat (pdv)  \
# 0              8.0          35.0          115.0                 64.0
# 1             36.0          24.0           59.0                  7.0
# 2              7.0          15.0           16.0                 12.0
# 3             17.0           0.0           34.0                 11.0
# 4             46.0          84.0           60.0                 61.0
# ...            ...           ...            ...                  ...
# 76733         15.0          24.0           40.0                 33.0
# 76734         35.0          67.0           84.0                 41.0
# 76735         25.0          23.0           79.0                 23.0
# 76736         12.0          12.0           11.0                 73.0
# 76737         21.0          49.0           28.0                 64.0
#
#        carbohydrates (pdv)
# 0                      4.0
# 1                      7.0
# 2                     10.0
# 3                     18.0
# 4                      8.0
# ...                    ...
# 76733                 29.0
# 76734                 17.0
# 76735                  3.0
# 76736                 12.0
# 76737                 12.0
#
# [76738 rows x 10 columns]

# %%
df['Predicts'] = df['Predicts'].tolist()
df['Predicts'].value_counts()
# Out:
# invalid pairing                                                 4754
# ['riesling off-dry' 'chenin blanc off-dry' 'gewurztraminer']     836
# ['riesling off-dry' 'chenin blanc off-dry' 'pinot noir']         544
# ['chenin blanc off-dry' 'riesling off-dry' 'pinot noir']         450
# ['chenin blanc off-dry' 'riesling off-dry' 'gewurztraminer']     427
#                                                                 ...
# ['riesling off-dry' 'malbec' 'tempranillo']                        1
# ['cabernet franc' 'viognier' 'pinot noir']                         1
# ['cabernet franc' 'pinot noir' 'chenin blanc off-dry']             1
# ['champagne' 'cabernet franc' 'touriga nacional']                  1
# ['riesling dry' 'chardonnay' 'nebbiolo']                           1
# Name: Predicts, Length: 4773, dtype: int64

# %%
cabernet_sauvignon_df = df[df['Predicts'].str.contains('cabernet sauvignon')]
merlot_df = df[df['Predicts'].str.contains('merlot')]
syrah_df = df[df['Predicts'].str.contains('syrah')]
malbec_df = df[df['Predicts'].str.contains('malbec')]
pinot_noir_df = df[df['Predicts'].str.contains('pinot noir')]
sangiovese_df = df[df['Predicts'].str.contains('sangiovese')]
chardonnay_df = df[df['Predicts'].str.contains('chardonnay')]
sauvignon_blanc_df = df[df['Predicts'].str.contains('sauvignon blanc')]
riesling_dry_df = df[df['Predicts'].str.contains('riesling dry')]
riesling_off_dry_df = df[df['Predicts'].str.contains('riesling off-dry')]
gewurztraminer_df = df[df['Predicts'].str.contains('gewurztraminer')]
chenin_blanc_dry_df = df[df['Predicts'].str.contains('chenin blanc dry')]
chenin_blanc_off_dry_df = df[df['Predicts'].str.contains('chenin blanc off')]
mourvedre_df = df[df['Predicts'].str.contains('mourvedre')]
pinotage_df = df[df['Predicts'].str.contains('pinotage')]
petite_sirah_df = df[df['Predicts'].str.contains('petite sirah')]
touriga_nacional_df = df[df['Predicts'].str.contains('touriga nacional')]
bordeaux_blend_df = df[df['Predicts'].str.contains('bordeaux blend')]
zinfandel_df = df[df['Predicts'].str.contains('zinfandel')]
cabernet_franc_df = df[df['Predicts'].str.contains('cabernet franc')]
tempranillo_df = df[df['Predicts'].str.contains('tempranillo')]
nebbiolo_df = df[df['Predicts'].str.contains('nebbiolo')]
barbera_df = df[df['Predicts'].str.contains('barbera')]
carignan_df = df[df['Predicts'].str.contains('carignan')]
rhone_blend_df = df[df['Predicts'].str.contains('rhone blend')]
grenache_df = df[df['Predicts'].str.contains('grenache')]
gamay_df = df[df['Predicts'].str.contains('gamay')]
st_laurent_df = df[df['Predicts'].str.contains('st. laurent')]
provencal_rose_df = df[df['Predicts'].str.contains('provencal rose')]
white_zinfandel_df = df[df['Predicts'].str.contains('white zinfandel')]
dry_rose_df = df[df['Predicts'].str.contains('dry rose')]
viognier_df = df[df['Predicts'].str.contains('viognier')]
marsanne_blend_df = df[df['Predicts'].str.contains('marsanne blend')]
albarino_df = df[df['Predicts'].str.contains('albariño')]
pinot_blanc_df = df[df['Predicts'].str.contains('pinot blanc')]
vermentino_df = df[df['Predicts'].str.contains('vermentino')]
melon_df = df[df['Predicts'].str.contains('melon de bourgogne')]
garganega_df = df[df['Predicts'].str.contains('garganega')]
pinot_gris_df = df[df['Predicts'].str.contains('pinot gris/grigio')]
champagne_df = df[df['Predicts'].str.contains('marsanne blend')]

# %%
grapes = ['cabernet sauvignon','merlot', 'syrah', 'malbec', 'pinot noir', 'sangiovese', 'chardonnay', 'sauvignon blanc', 'riesling dry', 'riesling off-dry', 
'gewurztraminer',
'chenin blanc dry',
'chenin blanc off-dry',
'mourvedre',
'pinotage',
'petite sirah',
'touriga nacional',
'bordeaux blend',
'zinfandel',
'cabernet franc',
'tempranillo',
'nebbiolo',
'barbera',
'carignan',
'rhone blend',
'grenache',
'gamay',
'st. laurent',
'provencal rose',
'white zinfandel',
'dry rose',
'viognier',
'marsanne blend',
'albariño',
'pinot blanc',
'vermentino',
'melon de bourgogne',
'garganega',
'pinot gris/grigio',
'champagne']

# %%
cab_comparables = []
for grape in grapes:
    percent_shared = ((cabernet_sauvignon_df['Predicts'].str.contains(grape) == True).mean().round(3))
    cab_comparables.append(percent_shared)

merlot_comparables = []
for grape in grapes:
    percent_shared = ((merlot_df['Predicts'].str.contains(grape) == True).mean().round(3))
    merlot_comparables.append(percent_shared)
    
syrah_comparables = []
for grape in grapes:
    percent_shared = ((syrah_df['Predicts'].str.contains(grape) == True).mean().round(3))
    syrah_comparables.append(percent_shared)
    
malbec_comparables = []
for grape in grapes:
    percent_shared = ((malbec_df['Predicts'].str.contains(grape) == True).mean().round(3))
    malbec_comparables.append(percent_shared)
    
pinot_noir_comparables = []
for grape in grapes:
    percent_shared = ((pinot_noir_df['Predicts'].str.contains(grape) == True).mean().round(3))
    pinot_noir_comparables.append(percent_shared)

sangiovese_comparables = []
for grape in grapes:
    percent_shared = ((sangiovese_df['Predicts'].str.contains(grape) == True).mean().round(3))
    sangiovese_comparables.append(percent_shared)

chardonnay_comparables = []
for grape in grapes:
    percent_shared = ((chardonnay_df['Predicts'].str.contains(grape) == True).mean().round(3))
    chardonnay_comparables.append(percent_shared)
    
sauvignon_blanc_comparables = []
for grape in grapes:
    percent_shared = ((sauvignon_blanc_df['Predicts'].str.contains(grape) == True).mean().round(3))
    sauvignon_blanc_comparables.append(percent_shared)
    
riesling_dry_comparables = []
for grape in grapes:
    percent_shared = ((riesling_dry_df['Predicts'].str.contains(grape) == True).mean().round(3))
    riesling_dry_comparables.append(percent_shared)
    
riesling_off_dry_comparables = []
for grape in grapes:
    percent_shared = ((riesling_off_dry_df['Predicts'].str.contains(grape) == True).mean().round(3))
    riesling_off_dry_comparables.append(percent_shared)

gewurztraminer_comparables = []
for grape in grapes:
    percent_shared = ((gewurztraminer_df['Predicts'].str.contains(grape) == True).mean().round(3))
    gewurztraminer_comparables.append(percent_shared)

chenin_blanc_dry_comparables = []
for grape in grapes:
    percent_shared = ((chenin_blanc_dry_df['Predicts'].str.contains(grape) == True).mean().round(3))
    chenin_blanc_dry_comparables.append(percent_shared)
   
    
chenin_blanc_off_dry_comparables = []
for grape in grapes:
    percent_shared = ((chenin_blanc_off_dry_df['Predicts'].str.contains(grape) == True).mean().round(3))
    chenin_blanc_off_dry_comparables.append(percent_shared)
    
mourvedre_comparables = []
for grape in grapes:
    percent_shared = ((mourvedre_df['Predicts'].str.contains(grape) == True).mean().round(3))
    mourvedre_comparables.append(percent_shared)
    
pinotage_comparables = []
for grape in grapes:
    percent_shared = ((pinotage_df['Predicts'].str.contains(grape) == True).mean().round(3))
    pinotage_comparables.append(percent_shared)
    
petite_sirah_comparables = []
for grape in grapes:
    percent_shared = ((petite_sirah_df['Predicts'].str.contains(grape) == True).mean().round(4))
    petite_sirah_comparables.append(percent_shared)
     

touriga_nacional_comparables = []
for grape in grapes:
    percent_shared = ((touriga_nacional_df['Predicts'].str.contains(grape) == True).mean().round(3))
    touriga_nacional_comparables.append(percent_shared)
    
bordeaux_blend_comparables = []
for grape in grapes:
    percent_shared = ((bordeaux_blend_df['Predicts'].str.contains(grape) == True).mean().round(3))
    bordeaux_blend_comparables.append(percent_shared)
    
zinfandel_comparables = []
for grape in grapes:
    percent_shared = ((zinfandel_df['Predicts'].str.contains(grape) == True).mean().round(3))
    zinfandel_comparables.append(percent_shared)
    
cabernet_franc_comparables = []
for grape in grapes:
    percent_shared = ((cabernet_franc_df['Predicts'].str.contains(grape) == True).mean().round(3))
    cabernet_franc_comparables.append(percent_shared)
    
tempranillo_comparables = []
for grape in grapes:
    percent_shared = ((tempranillo_df['Predicts'].str.contains(grape) == True).mean().round(3))
    tempranillo_comparables.append(percent_shared)
    
nebbiolo_comparables = []
for grape in grapes:
    percent_shared = ((nebbiolo_df['Predicts'].str.contains(grape) == True).mean().round(3))
    nebbiolo_comparables.append(percent_shared)
    
barbera_comparables = []
for grape in grapes:
    percent_shared = ((barbera_df['Predicts'].str.contains(grape) == True).mean().round(3))
    barbera_comparables.append(percent_shared)
    
carignan_comparables = []
for grape in grapes:
    percent_shared = ((carignan_df['Predicts'].str.contains(grape) == True).mean().round(3))
    carignan_comparables.append(percent_shared)
    
rhone_blend_comparables = []
for grape in grapes:
    percent_shared = ((rhone_blend_df['Predicts'].str.contains(grape) == True).mean().round(3))
    rhone_blend_comparables.append(percent_shared)
    
grenache_comparables = []
for grape in grapes:
    percent_shared = ((grenache_df['Predicts'].str.contains(grape) == True).mean().round(3))
    grenache_comparables.append(percent_shared)
    
gamay_comparables = []
for grape in grapes:
    percent_shared = ((gamay_df['Predicts'].str.contains(grape) == True).mean().round(3))
    gamay_comparables.append(percent_shared)
    
st_laurent_comparables = []
for grape in grapes:
    percent_shared = ((st_laurent_df['Predicts'].str.contains(grape) == True).mean().round(3))
    st_laurent_comparables.append(percent_shared)
    
provencal_rose_comparables = []
for grape in grapes:
    percent_shared = ((provencal_rose_df['Predicts'].str.contains(grape) == True).mean().round(3))
    provencal_rose_comparables.append(percent_shared)

white_zinfandel_comparables = []
for grape in grapes:
    percent_shared = ((white_zinfandel_df['Predicts'].str.contains(grape) == True).mean().round(3))
    white_zinfandel_comparables.append(percent_shared)
    
dry_rose_comparables = []
for grape in grapes:
    percent_shared = ((dry_rose_df['Predicts'].str.contains(grape) == True).mean().round(3))
    dry_rose_comparables.append(0)
    
viognier_comparables = []
for grape in grapes:
    percent_shared = ((viognier_df['Predicts'].str.contains(grape) == True).mean().round(3))
    viognier_comparables.append(percent_shared)
    
marsanne_blend_comparables = []
for grape in grapes:
    percent_shared = ((marsanne_blend_df['Predicts'].str.contains(grape) == True).mean().round(3))
    marsanne_blend_comparables.append(percent_shared)
    
albarino_comparables = []
for grape in grapes:
    percent_shared = ((albarino_df['Predicts'].str.contains(grape) == True).mean().round(3))
    albarino_comparables.append(percent_shared)
    
pinot_blanc_comparables = []
for grape in grapes:
    percent_shared = ((pinot_blanc_df['Predicts'].str.contains(grape) == True).mean().round(3))
    pinot_blanc_comparables.append(percent_shared)
    
vermentino_comparables = []
for grape in grapes:
    percent_shared = ((vermentino_df['Predicts'].str.contains(grape) == True).mean().round(3))
    vermentino_comparables.append(percent_shared)
    
melon_comparables = []
for grape in grapes:
    percent_shared = ((melon_df['Predicts'].str.contains(grape) == True).mean().round(3))
    melon_comparables.append(percent_shared)
    
garganega_comparables = []
for grape in grapes:
    percent_shared = ((garganega_df['Predicts'].str.contains(grape) == True).mean().round(3))
    garganega_comparables.append(percent_shared)
   
    
pinot_gris_comparables = []
for grape in grapes:
    percent_shared = ((pinot_gris_df['Predicts'].str.contains(grape) == True).mean().round(3))
    pinot_gris_comparables.append(percent_shared)
        
champagne_comparables = []
for grape in grapes:
    percent_shared = ((champagne_df['Predicts'].str.contains(grape) == True).mean().round(3))
    champagne_comparables.append(percent_shared)
    

data = [cab_comparables,
        merlot_comparables, 
        syrah_comparables, 
        malbec_comparables, 
        pinot_noir_comparables, 
        sangiovese_comparables, 
        chardonnay_comparables, 
        sauvignon_blanc_comparables,
        riesling_dry_comparables,
        riesling_off_dry_comparables,
        gewurztraminer_comparables,
        chenin_blanc_dry_comparables,
        chenin_blanc_off_dry_comparables,
        mourvedre_comparables,
        pinotage_comparables,
        petite_sirah_comparables,
        touriga_nacional_comparables,
        bordeaux_blend_comparables,
        zinfandel_comparables,
        cabernet_franc_comparables,
        tempranillo_comparables,
        nebbiolo_comparables,
        barbera_comparables, 
        carignan_comparables, 
        rhone_blend_comparables,
        grenache_comparables, 
        gamay_comparables,
        st_laurent_comparables,
        provencal_rose_comparables,
        white_zinfandel_comparables,
        dry_rose_comparables,
        viognier_comparables,
        marsanne_blend_comparables, 
        albarino_comparables,
        pinot_blanc_comparables, 
        vermentino_comparables, 
        melon_comparables,
        garganega_comparables,
        pinot_gris_comparables,
        champagne_comparables
       ]
comp_df = pd.DataFrame(data, columns = grapes, index = grapes)

# %%
comp_df
# Out:
#                       cabernet sauvignon  merlot   syrah  malbec  pinot noir  \
# cabernet sauvignon                 1.000  0.0000  0.2160   0.759      0.0060
# merlot                             0.000  1.0000  0.0060   0.004      0.2380
# syrah                              0.137  0.0130  1.0000   0.485      0.0630
# malbec                             0.330  0.0060  0.3330   1.000      0.0490
# pinot noir                         0.001  0.0840  0.0110   0.012      1.0000
# sangiovese                         0.003  0.2240  0.0180   0.048      0.2870
# chardonnay                         0.000  0.0360  0.0000   0.003      0.3480
# sauvignon blanc                    0.000  0.0080  0.0000   0.001      0.1570
# riesling dry                       0.000  0.0000  0.0000   0.001      0.0910
# riesling off-dry                   0.000  0.0250  0.0050   0.001      0.2520
# gewurztraminer                     0.000  0.0110  0.0020   0.001      0.2610
# chenin blanc dry                   0.000  0.0140  0.0000   0.000      0.5240
# chenin blanc off-dry               0.000  0.0190  0.0020   0.000      0.2840
# mourvedre                          0.053  0.0150  0.3040   0.635      0.0370
# pinotage                           0.167  0.0090  0.3410   0.458      0.0000
# petite sirah                       0.057  0.0274  0.1716   0.292      0.0094
# touriga nacional                   0.153  0.0280  0.1030   0.300      0.0040
# bordeaux blend                     0.055  0.2550  0.1070   0.223      0.0590
# zinfandel                          0.000  0.0420  0.0560   0.121      0.2440
# cabernet franc                     0.001  0.2750  0.0080   0.010      0.1850
# tempranillo                        0.030  0.1640  0.1170   0.081      0.2770
# nebbiolo                           0.109  0.2060  0.1130   0.210      0.0520
# barbera                            0.000  0.0770  0.1380   0.046      0.0920
# carignan                           0.000  0.1220  0.0020   0.009      0.2970
# rhone blend                        0.000  0.0780  0.1300   0.104      0.3890
# grenache                           0.000  0.0460  0.0000   0.003      0.3590
# gamay                              0.000  0.0750  0.0000   0.000      0.2780
# st. laurent                        0.000  0.0030  0.0710   0.000      0.6850
# provencal rose                     0.000  0.0000  0.0000   0.000      0.0240
# white zinfandel                    0.000  0.0000  0.0000   0.000      0.0000
# dry rose                           0.000  0.0000  0.0000   0.000      0.0000
# viognier                           0.000  0.0650  0.0000   0.000      0.1070
# marsanne blend                     0.000  0.0020  0.0000   0.000      0.0460
# albariño                           0.000  0.0000  0.0000   0.001      0.0300
# pinot blanc                        0.000  0.0000  0.0000   0.000      0.0310
# vermentino                         0.000  0.0000  0.0000   0.000      0.0090
# melon de bourgogne                 0.000  0.0000  0.0000   0.000      0.0180
# garganega                          0.000  0.0010  0.0000   0.000      0.0870
# pinot gris/grigio                  0.000  0.0000  0.0000   0.000      0.0050
# champagne                          0.000  0.0020  0.0000   0.000      0.0460
#
#                       sangiovese  chardonnay  sauvignon blanc  riesling dry  \
# cabernet sauvignon        0.0170       0.000            0.000         0.000
# merlot                    0.3760       0.092            0.009         0.001
# syrah                     0.0630       0.000            0.000         0.000
# malbec                    0.1160       0.010            0.001         0.002
# pinot noir                0.1700       0.314            0.058         0.045
# sangiovese                1.0000       0.098            0.050         0.010
# chardonnay                0.0640       1.000            0.135         0.175
# sauvignon blanc           0.0800       0.330            1.000         0.437
# riesling dry              0.0120       0.317            0.325         1.000
# riesling off-dry          0.0380       0.139            0.068         0.188
# gewurztraminer            0.0860       0.237            0.035         0.075
# chenin blanc dry          0.0120       0.352            0.046         0.082
# chenin blanc off-dry      0.0100       0.186            0.010         0.113
# mourvedre                 0.1020       0.000            0.000         0.000
# pinotage                  0.0000       0.000            0.000         0.000
# petite sirah              0.0281       0.000            0.000         0.000
# touriga nacional          0.0450       0.000            0.000         0.002
# bordeaux blend            0.1130       0.001            0.000         0.000
# zinfandel                 0.2530       0.179            0.000         0.031
# cabernet franc            0.3580       0.032            0.019         0.003
# tempranillo               0.2870       0.029            0.015         0.006
# nebbiolo                  0.2530       0.004            0.001         0.003
# barbera                   0.2310       0.015            0.000         0.000
# carignan                  0.3600       0.173            0.010         0.004
# rhone blend               0.0760       0.065            0.000         0.000
# grenache                  0.3340       0.247            0.072         0.032
# gamay                     0.0550       0.243            0.081         0.071
# st. laurent               0.0620       0.218            0.059         0.010
# provencal rose            0.0000       0.141            0.303         0.421
# white zinfandel           0.0000       0.059            0.000         0.314
# dry rose                  0.0000       0.000            0.000         0.000
# viognier                  0.0380       0.330            0.053         0.033
# marsanne blend            0.0260       0.579            0.009         0.041
# albariño                  0.0120       0.233            0.625         0.431
# pinot blanc               0.0020       0.480            0.102         0.164
# vermentino                0.0010       0.303            0.248         0.345
# melon de bourgogne        0.0000       0.049            0.584         0.785
# garganega                 0.0160       0.140            0.254         0.468
# pinot gris/grigio         0.0010       0.435            0.143         0.388
# champagne                 0.0260       0.579            0.009         0.041
#
#                       riesling off-dry  ...  dry rose  viognier  \
# cabernet sauvignon              0.0000  ...     0.000     0.000
# merlot                          0.0600  ...     0.000     0.063
# syrah                           0.0230  ...     0.000     0.000
# malbec                          0.0020  ...     0.000     0.000
# pinot noir                      0.2190  ...     0.000     0.037
# sangiovese                      0.0560  ...     0.000     0.022
# chardonnay                      0.1340  ...     0.002     0.126
# sauvignon blanc                 0.1600  ...     0.009     0.049
# riesling dry                    0.3290  ...     0.001     0.023
# riesling off-dry                1.0000  ...     0.000     0.092
# gewurztraminer                  0.4150  ...     0.001     0.139
# chenin blanc dry                0.1960  ...     0.000     0.013
# chenin blanc off-dry            0.6340  ...     0.000     0.129
# mourvedre                       0.0010  ...     0.000     0.000
# pinotage                        0.0000  ...     0.000     0.000
# petite sirah                    0.0007  ...     0.000     0.000
# touriga nacional                0.0000  ...     0.000     0.000
# bordeaux blend                  0.0050  ...     0.000     0.000
# zinfandel                       0.0560  ...     0.000     0.043
# cabernet franc                  0.1100  ...     0.000     0.092
# tempranillo                     0.0810  ...     0.000     0.035
# nebbiolo                        0.0430  ...     0.000     0.004
# barbera                         0.0000  ...     0.000     0.062
# carignan                        0.1680  ...     0.000     0.060
# rhone blend                     0.0020  ...     0.000     0.010
# grenache                        0.0330  ...     0.000     0.151
# gamay                           0.2210  ...     0.002     0.231
# st. laurent                     0.1570  ...     0.000     0.075
# provencal rose                  0.0540  ...     0.038     0.015
# white zinfandel                 0.2940  ...     0.000     0.118
# dry rose                        0.0000  ...     0.000     0.000
# viognier                        0.2330  ...     0.001     1.000
# marsanne blend                  0.1830  ...     0.000     0.223
# albariño                        0.0620  ...     0.019     0.004
# pinot blanc                     0.1480  ...     0.029     0.195
# vermentino                      0.0480  ...     0.026     0.006
# melon de bourgogne              0.1760  ...     0.009     0.000
# garganega                       0.0950  ...     0.062     0.000
# pinot gris/grigio               0.0650  ...     0.002     0.034
# champagne                       0.1830  ...     0.000     0.223
#
#                       marsanne blend  albariño  pinot blanc  vermentino  \
# cabernet sauvignon             0.000     0.000        0.000       0.000
# merlot                         0.001     0.000        0.000       0.000
# syrah                          0.000     0.000        0.000       0.000
# malbec                         0.000     0.001        0.000       0.000
# pinot noir                     0.006     0.004        0.001       0.000
# sangiovese                     0.006     0.003        0.000       0.000
# chardonnay                     0.086     0.032        0.013       0.012
# sauvignon blanc                0.003     0.207        0.007       0.025
# riesling dry                   0.011     0.106        0.008       0.026
# riesling off-dry               0.028     0.009        0.004       0.002
# gewurztraminer                 0.059     0.001        0.008       0.005
# chenin blanc dry               0.001     0.001        0.002       0.007
# chenin blanc off-dry           0.043     0.003        0.002       0.001
# mourvedre                      0.000     0.000        0.000       0.000
# pinotage                       0.000     0.000        0.000       0.000
# petite sirah                   0.000     0.000        0.000       0.000
# touriga nacional               0.000     0.000        0.000       0.000
# bordeaux blend                 0.000     0.001        0.000       0.000
# zinfandel                      0.031     0.000        0.027       0.000
# cabernet franc                 0.000     0.001        0.000       0.000
# tempranillo                    0.001     0.000        0.000       0.000
# nebbiolo                       0.000     0.000        0.000       0.000
# barbera                        0.000     0.000        0.000       0.000
# carignan                       0.011     0.000        0.001       0.000
# rhone blend                    0.000     0.000        0.000       0.000
# grenache                       0.002     0.004        0.000       0.002
# gamay                          0.014     0.022        0.006       0.000
# st. laurent                    0.001     0.000        0.001       0.000
# provencal rose                 0.020     0.368        0.018       0.036
# white zinfandel                0.333     0.000        0.294       0.000
# dry rose                       0.000     0.000        0.000       0.000
# viognier                       0.087     0.001        0.014       0.001
# marsanne blend                 1.000     0.014        0.009       0.027
# albariño                       0.015     1.000        0.024       0.035
# pinot blanc                    0.051     0.117        1.000       0.119
# vermentino                     0.098     0.114        0.079       1.000
# melon de bourgogne             0.000     0.127        0.008       0.011
# garganega                      0.000     0.042        0.058       0.121
# pinot gris/grigio              0.098     0.197        0.011       0.040
# champagne                      1.000     0.014        0.009       0.027
#
#                       melon de bourgogne  garganega  pinot gris/grigio  \
# cabernet sauvignon                 0.000      0.000              0.000
# merlot                             0.000      0.000              0.000
# syrah                              0.000      0.000              0.000
# malbec                             0.000      0.000              0.000
# pinot noir                         0.001      0.003              0.000
# sangiovese                         0.000      0.001              0.000
# chardonnay                         0.002      0.005              0.025
# sauvignon blanc                    0.069      0.023              0.020
# riesling dry                       0.069      0.031              0.040
# riesling off-dry                   0.009      0.004              0.004
# gewurztraminer                     0.000      0.014              0.002
# chenin blanc dry                   0.001      0.003              0.027
# chenin blanc off-dry               0.000      0.006              0.001
# mourvedre                          0.000      0.000              0.000
# pinotage                           0.000      0.000              0.000
# petite sirah                       0.000      0.000              0.000
# touriga nacional                   0.000      0.000              0.000
# bordeaux blend                     0.000      0.000              0.000
# zinfandel                          0.027      0.000              0.000
# cabernet franc                     0.000      0.000              0.000
# tempranillo                        0.000      0.000              0.000
# nebbiolo                           0.000      0.000              0.000
# barbera                            0.000      0.000              0.000
# carignan                           0.000      0.000              0.000
# rhone blend                        0.000      0.000              0.000
# grenache                           0.002      0.012              0.001
# gamay                              0.001      0.001              0.005
# st. laurent                        0.013      0.008              0.000
# provencal rose                     0.095      0.003              0.074
# white zinfandel                    0.294      0.000              0.000
# dry rose                           0.000      0.000              0.000
# viognier                           0.000      0.000              0.005
# marsanne blend                     0.000      0.000              0.038
# albariño                           0.046      0.011              0.083
# pinot blanc                        0.014      0.078              0.023
# vermentino                         0.013      0.108              0.055
# melon de bourgogne                 1.000      0.070              0.004
# garganega                          0.092      1.000              0.000
# pinot gris/grigio                  0.004      0.000              1.000
# champagne                          0.000      0.000              0.038
#
#                       champagne
# cabernet sauvignon       0.0020
# merlot                   0.0000
# syrah                    0.0020
# malbec                   0.0080
# pinot noir               0.0620
# sangiovese               0.0300
# chardonnay               0.2270
# sauvignon blanc          0.1570
# riesling dry             0.2460
# riesling off-dry         0.0160
# gewurztraminer           0.0470
# chenin blanc dry         0.2500
# chenin blanc off-dry     0.0210
# mourvedre                0.0030
# pinotage                 0.0060
# petite sirah             0.0058
# touriga nacional         0.0080
# bordeaux blend           0.0000
# zinfandel                0.0020
# cabernet franc           0.0200
# tempranillo              0.0130
# nebbiolo                 0.0050
# barbera                  0.0150
# carignan                 0.0030
# rhone blend              0.0050
# grenache                 0.0530
# gamay                    0.0580
# st. laurent              0.0450
# provencal rose           0.2210
# white zinfandel          0.0000
# dry rose                 0.0000
# viognier                 0.0570
# marsanne blend           0.2280
# albariño                 0.1940
# pinot blanc              0.0510
# vermentino               0.3940
# melon de bourgogne       0.0270
# garganega                0.1210
# pinot gris/grigio        0.4160
# champagne                0.2280
#
# [40 rows x 40 columns]

# %%
bordeaux_comparables = []
for grape in grapes:
    percent_shared = bordeaux_blend_df['Predicts'].str.contains(grape).value_counts(True)
    bordeaux_comparables.append({grape: percent_shared})
bordeaux_comparables
# Out:
# [{'cabernet sauvignon': False    0.961839
#   True     0.038161
#   Name: Predicts, dtype: float64},
#  {'merlot': False    0.854713
#   True     0.145287
#   Name: Predicts, dtype: float64},
#  {'syrah': False    0.886897
#   True     0.113103
#   Name: Predicts, dtype: float64},
#  {'malbec': False    0.785287
#   True     0.214713
#   Name: Predicts, dtype: float64},
#  {'pinot noir': False    0.936092
#   True     0.063908
#   Name: Predicts, dtype: float64},
#  {'sangiovese': False    0.889195
#   True     0.110805
#   Name: Predicts, dtype: float64},
#  {'chardonnay': False    0.996782
#   True     0.003218
#   Name: Predicts, dtype: float64},
#  {'sauvignon blanc': False    1.0
#   Name: Predicts, dtype: float64},
#  {'riesling dry': False    1.0
#   Name: Predicts, dtype: float64},
#  {'riesling off-dry': False    0.989425
#   True     0.010575
#   Name: Predicts, dtype: float64},
#  {'gewurztraminer': False    0.99908
#   True     0.00092
#   Name: Predicts, dtype: float64},
#  {'chenin blanc dry': False    1.0
#   Name: Predicts, dtype: float64},
#  {'chenin blanc off-dry': False    0.993563
#   True     0.006437
#   Name: Predicts, dtype: float64},
#  {'mourvedre': False    0.992184
#   True     0.007816
#   Name: Predicts, dtype: float64},
#  {'pinotage': False    0.994023
#   True     0.005977
#   Name: Predicts, dtype: float64},
#  {'petite sirah': False    0.947586
#   True     0.052414
#   Name: Predicts, dtype: float64},
#  {'touriga nacional': False    0.975632
#   True     0.024368
#   Name: Predicts, dtype: float64},
#  {'bordeaux blend': True    1.0
#   Name: Predicts, dtype: float64},
#  {'zinfandel': False    0.995862
#   True     0.004138
#   Name: Predicts, dtype: float64},
#  {'cabernet franc': False    0.933333
#   True     0.066667
#   Name: Predicts, dtype: float64},
#  {'tempranillo': False    0.583908
#   True     0.416092
#   Name: Predicts, dtype: float64},
#  {'nebbiolo': True     0.68092
#   False    0.31908
#   Name: Predicts, dtype: float64},
#  {'barbera': False    0.994023
#   True     0.005977
#   Name: Predicts, dtype: float64},
#  {'carignan': False    0.993563
#   True     0.006437
#   Name: Predicts, dtype: float64},
#  {'rhone blend': False    0.989425
#   True     0.010575
#   Name: Predicts, dtype: float64},
#  {'grenache': False    0.99954
#   True     0.00046
#   Name: Predicts, dtype: float64},
#  {'gamay': False    0.99954
#   True     0.00046
#   Name: Predicts, dtype: float64},
#  {'st. laurent': False    1.0
#   Name: Predicts, dtype: float64},
#  {'provencal rose': False    1.0
#   Name: Predicts, dtype: float64},
#  {'white zinfandel': False    1.0
#   Name: Predicts, dtype: float64},
#  {'dry rose': False    1.0
#   Name: Predicts, dtype: float64},
#  {'viognier': False    1.0
#   Name: Predicts, dtype: float64},
#  {'marsanne blend': False    1.0
#   Name: Predicts, dtype: float64},
#  {'albariño': False    0.99954
#   True     0.00046
#   Name: Predicts, dtype: float64},
#  {'pinot blanc': False    1.0
#   Name: Predicts, dtype: float64},
#  {'vermentino': False    1.0
#   Name: Predicts, dtype: float64},
#  {'melon de bourgogne': False    1.0
#   Name: Predicts, dtype: float64},
#  {'garganega': False    1.0
#   Name: Predicts, dtype: float64},
#  {'pinot gris/grigio': False    1.0
#   Name: Predicts, dtype: float64},
#  {'champagne': False    0.989885
#   True     0.010115
#   Name: Predicts, dtype: float64}]
