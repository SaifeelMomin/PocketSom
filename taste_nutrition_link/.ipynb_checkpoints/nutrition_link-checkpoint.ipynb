# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = os.path.join("df_main.csv")
df = pd.read_csv(path)
df.columns
# Out:
# Index(['Unnamed: 0', 'category', 'beverage', 'food', 'rating', 'recipeName',
#        'nutrition', 'ingred', 'ingr_count'],
#       dtype='object')

# %%
wine = df[["category", "beverage", "food", "nutrition"]]
wine
# Out:
#           category                beverage                         food  \
# 0       White Wine                Sancerre                Chevre Cheese
# 1       White Wine                Sancerre                  Goat Cheese
# 2       White Wine  Gewürztraminer, Alsace              Muenster Cheese
# 3     Dessert Wine               Sauternes             Roquefort Cheese
# 4     Dessert Wine                 Banyuls               Dark Chocolate
# ...            ...                     ...                          ...
# 7780    White Wine          Grenache Blanc              Roasted Peppers
# 7781    White Wine          Grenache Blanc                     Marjoram
# 7782      Red Wine              Beaujolais  Seafood Macaroni and Cheese
# 7783      Red Wine      Cabernet Sauvignon               Dark Chocolate
# 7784      Red Wine              Pinot Noir  Seafood Macaroni and Cheese
#
#                                         nutrition
# 0      [260.2, 32.0, 10.0, 17.0, 20.0, 68.0, 2.0]
# 1       [269.3, 25.0, 7.0, 15.0, 14.0, 52.0, 8.0]
# 2       [414.4, 36.0, 6.0, 26.0, 63.0, 55.0, 4.0]
# 3      [226.2, 8.0, 162.0, 13.0, 9.0, 16.0, 14.0]
# 4           [80.9, 1.0, 67.0, 0.0, 2.0, 2.0, 6.0]
# ...                                           ...
# 7780  [769.6, 49.0, 17.0, 56.0, 56.0, 69.0, 30.0]
# 7781         [64.1, 0.0, 3.0, 0.0, 5.0, 0.0, 4.0]
# 7782                                          NaN
# 7783        [80.9, 1.0, 67.0, 0.0, 2.0, 2.0, 6.0]
# 7784                                          NaN
#
# [7785 rows x 4 columns]

# %%
wine = wine.dropna(subset=['nutrition'])
wine
# Out:
#           category                beverage              food  \
# 0       White Wine                Sancerre     Chevre Cheese
# 1       White Wine                Sancerre       Goat Cheese
# 2       White Wine  Gewürztraminer, Alsace   Muenster Cheese
# 3     Dessert Wine               Sauternes  Roquefort Cheese
# 4     Dessert Wine                 Banyuls    Dark Chocolate
# ...            ...                     ...               ...
# 7778    White Wine          Grenache Blanc          Eggplant
# 7779    White Wine          Grenache Blanc     Yellow Squash
# 7780    White Wine          Grenache Blanc   Roasted Peppers
# 7781    White Wine          Grenache Blanc          Marjoram
# 7783      Red Wine      Cabernet Sauvignon    Dark Chocolate
#
#                                         nutrition
# 0      [260.2, 32.0, 10.0, 17.0, 20.0, 68.0, 2.0]
# 1       [269.3, 25.0, 7.0, 15.0, 14.0, 52.0, 8.0]
# 2       [414.4, 36.0, 6.0, 26.0, 63.0, 55.0, 4.0]
# 3      [226.2, 8.0, 162.0, 13.0, 9.0, 16.0, 14.0]
# 4           [80.9, 1.0, 67.0, 0.0, 2.0, 2.0, 6.0]
# ...                                           ...
# 7778  [537.9, 31.0, 31.0, 11.0, 37.0, 55.0, 24.0]
# 7779  [354.8, 32.0, 12.0, 45.0, 24.0, 64.0, 11.0]
# 7780  [769.6, 49.0, 17.0, 56.0, 56.0, 69.0, 30.0]
# 7781         [64.1, 0.0, 3.0, 0.0, 5.0, 0.0, 4.0]
# 7783        [80.9, 1.0, 67.0, 0.0, 2.0, 2.0, 6.0]
#
# [5371 rows x 4 columns]

# %%
wine[["calories", "total fat", "sugar", "sodium", "protein", "saturated fat", "carbohydrates"]] = pd.DataFrame(wine.nutrition.values.tolist(), index = wine.index)
wine
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-56f5b3a58f24> in <module>
# ----> 1 wine[["calories", "total fat", "sugar", "sodium", "protein", "saturated fat", "carbohydrates"]] = pd.DataFrame(wine.nutrition.values.tolist(), index = wine.index)
#       2 wine
#
# ~\.virtualenvs\pandas-gJAnY7Kn\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2933             self._setitem_frame(key, value)
#    2934         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2935             self._setitem_array(key, value)
#    2936         else:
#    2937             # set column
#
# ~\.virtualenvs\pandas-gJAnY7Kn\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    2959             if isinstance(value, DataFrame):
#    2960                 if len(value.columns) != len(key):
# -> 2961                     raise ValueError("Columns must be same length as key")
#    2962                 for k1, k2 in zip(key, value.columns):
#    2963                     self[k1] = value[k2]
#
# ValueError: Columns must be same length as key
