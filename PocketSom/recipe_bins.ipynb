# %%
import pandas as pd
import re

# %%
#cleaning raw recipe data, dropping unneccesary columns, splitting nutrition info and converting it to numeric values
df_recipes = pd.read_csv("RAW_recipes.csv")

#eliminate desserts
df_recipes = df_recipes[df_recipes["tags"].str.contains('dessert') == False]
#drop unneeded columns
df_recipes = df_recipes.drop(columns = ["id", "minutes", "contributor_id", "submitted", "tags", "n_steps", "description"])
df_recipes = df_recipes.drop(columns = "steps")
#split, clean, numerify nutritional information
df_recipes[['calories (number)', 'total fat (PDV)', 'sugar (PDV)' , 'sodium (PDV)' , 'protein (PDV)' , 'saturated fat (PDV)', 'carbohydrates (PDV)']]=df_recipes['nutrition'].str.split(', ', expand=True,n=6)
df_recipes['calories (number)'] = df_recipes['calories (number)'].str.lstrip('[')
df_recipes = df_recipes.drop(columns = ["saturated fat (PDV)", "carbohydrates (PDV)", 'nutrition'])
df_recipes[['calories (number)', 'total fat (PDV)', 'sugar (PDV)' , 'sodium (PDV)' , 'protein (PDV)']] = df_recipes[['calories (number)', 'total fat (PDV)', 'sugar (PDV)' , 'sodium (PDV)' , 'protein (PDV)']].astype(float)
df_recipes
# Out:
#                                               name  \
# 0       arriba   baked winter squash mexican style
# 1                 a bit different  breakfast pizza
# 2                        all in the kitchen  chili
# 3                               alouette  potatoes
# 4               amish  tomato ketchup  for canning
# ...                                            ...
# 231630                                zydeco sauce
# 231631                          zydeco shrimp wrap
# 231632                                 zydeco soup
# 231633                            zydeco spice mix
# 231634                   zydeco ya ya deviled eggs
#
#                                               ingredients  n_ingredients  \
# 0       ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1       ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2       ['ground beef', 'yellow onions', 'diced tomato...             13
# 3       ['spreadable cheese with garlic and herbs', 'n...             11
# 4       ['tomato juice', 'apple cider vinegar', 'sugar...              8
# ...                                                   ...            ...
# 231630  ['mayonnaise', 'prepared horseradish', 'worces...              6
# 231631  ['white rice', 'vegetable oil', 'onion', 'gree...             11
# 231632  ['celery', 'onion', 'green sweet pepper', 'gar...             22
# 231633  ['paprika', 'salt', 'garlic powder', 'onion po...             13
# 231634  ['hard-cooked eggs', 'mayonnaise', 'dijon must...              8
#
#         calories (number)  total fat (PDV)  sugar (PDV)  sodium (PDV)  \
# 0                    51.5              0.0         13.0           0.0
# 1                   173.4             18.0          0.0          17.0
# 2                   269.8             22.0         32.0          48.0
# 3                   368.1             17.0         10.0           2.0
# 4                   352.9              1.0        337.0          23.0
# ...                   ...              ...          ...           ...
# 231630              239.9             30.0         19.0          22.0
# 231631              482.6             13.0         25.0          37.0
# 231632              415.2             26.0         34.0          26.0
# 231633               14.8              0.0          2.0          58.0
# 231634               59.2              6.0          2.0           3.0
#
#         protein (PDV)
# 0                 2.0
# 1                22.0
# 2                39.0
# 3                14.0
# 4                 3.0
# ...               ...
# 231630            1.0
# 231631           33.0
# 231632           44.0
# 231633            1.0
# 231634            6.0
#
# [188434 rows x 8 columns]

# %%
#create df of beef dishes by keyword
search_values = ['beef', 'hamburger', 'steak', 'veal', 'bison', 'buffalo']
beef_df = df_recipes[df_recipes["ingredients"].str.contains('|'.join(search_values))]
beef_df = pd.DataFrame(beef_df)
beef_df
# Out:
#                                                      name  \
# 2                               all in the kitchen  chili
# 18                                     chinese  chop suey
# 26                            fool the meat eaters  chili
# 27                                  forgotten  minestrone
# 31                         global gourmet  taco casserole
# ...                                                   ...
# 231583                     zuppa di cipolla al vino rosso
# 231604  zurcher geschnetzeltes  zurich style veal stri...
# 231605           zurich diced veal zurcher geschnetzeltes
# 231606               zurich ragout  zrcher geschnetzeltes
# 231623                         zwiebelfleisch  onion beef
#
#                                               ingredients  n_ingredients  \
# 2       ['ground beef', 'yellow onions', 'diced tomato...             13
# 18      ['celery', 'onion', 'ground pork', 'soy sauce'...              7
# 26      ['vegetarian ground beef', 'garlic', 'onion', ...             12
# 27      ['beef stew meat', 'water', 'tomatoes', 'beef ...             14
# 31      ['ground beef', 'onion', 'tomato sauce', 'taco...             12
# ...                                                   ...            ...
# 231583  ['beef broth', 'butter', 'onions', 'flour', 'o...             10
# 231604  ['veal cutlets', 'all-purpose flour', 'butter'...             14
# 231605  ['onion', 'mushrooms', 'veal', 'flour', 'butte...             10
# 231606  ['veal', 'veal kidneys', 'clarified butter', '...             13
# 231623  ['round steaks', 'butter', 'onions', 'marjoram...             11
#
#         calories (number)  total fat (PDV)  sugar (PDV)  sodium (PDV)  \
# 2                   269.8             22.0         32.0          48.0
# 18                  395.4             31.0         20.0          29.0
# 26                  295.6              3.0         56.0          76.0
# 27                  346.9             24.0         18.0          42.0
# 31                  456.8             40.0         34.0          67.0
# ...                   ...              ...          ...           ...
# 231583             9282.1            136.0        340.0         715.0
# 231604              478.8             51.0          8.0           7.0
# 231605              562.5             58.0         11.0          10.0
# 231606              278.8             22.0          5.0          12.0
# 231623              629.0             58.0         28.0           9.0
#
#         protein (PDV)
# 2                39.0
# 18               51.0
# 26               32.0
# 27               42.0
# 31               57.0
# ...               ...
# 231583          746.0
# 231604           63.0
# 231605           62.0
# 231606           38.0
# 231623           99.0
#
# [22096 rows x 8 columns]

# %%
# a serving of beef contains ~ 200 calories, so we're discarding all entries with calorie values much lower or higher than a realistic serving
beef_df = beef_df[(beef_df["calories (number)"] <700) & (beef_df["calories (number)"] >200) & (beef_df['sugar (PDV)']<50)]
beef_df
# Out:
#                                                      name  \
# 2                               all in the kitchen  chili
# 18                                     chinese  chop suey
# 27                                  forgotten  minestrone
# 31                         global gourmet  taco casserole
# 43                  immoral  sandwich filling  loose meat
# ...                                                   ...
# 231547                             zucchini salsa burgers
# 231604  zurcher geschnetzeltes  zurich style veal stri...
# 231605           zurich diced veal zurcher geschnetzeltes
# 231606               zurich ragout  zrcher geschnetzeltes
# 231623                         zwiebelfleisch  onion beef
#
#                                               ingredients  n_ingredients  \
# 2       ['ground beef', 'yellow onions', 'diced tomato...             13
# 18      ['celery', 'onion', 'ground pork', 'soy sauce'...              7
# 27      ['beef stew meat', 'water', 'tomatoes', 'beef ...             14
# 31      ['ground beef', 'onion', 'tomato sauce', 'taco...             12
# 43      ['ground beef', 'sugar', 'prepared yellow must...              8
# ...                                                   ...            ...
# 231547  ['ground beef', 'breadcrumbs', 'egg', 'zucchin...             13
# 231604  ['veal cutlets', 'all-purpose flour', 'butter'...             14
# 231605  ['onion', 'mushrooms', 'veal', 'flour', 'butte...             10
# 231606  ['veal', 'veal kidneys', 'clarified butter', '...             13
# 231623  ['round steaks', 'butter', 'onions', 'marjoram...             11
#
#         calories (number)  total fat (PDV)  sugar (PDV)  sodium (PDV)  \
# 2                   269.8             22.0         32.0          48.0
# 18                  395.4             31.0         20.0          29.0
# 27                  346.9             24.0         18.0          42.0
# 31                  456.8             40.0         34.0          67.0
# 43                  223.2             22.0          4.0           7.0
# ...                   ...              ...          ...           ...
# 231547              571.0             47.0         29.0          34.0
# 231604              478.8             51.0          8.0           7.0
# 231605              562.5             58.0         11.0          10.0
# 231606              278.8             22.0          5.0          12.0
# 231623              629.0             58.0         28.0           9.0
#
#         protein (PDV)
# 2                39.0
# 18               51.0
# 27               42.0
# 31               57.0
# 43               35.0
# ...               ...
# 231547           59.0
# 231604           63.0
# 231605           62.0
# 231606           38.0
# 231623           99.0
#
# [12956 rows x 8 columns]

# %%
search_values2 = ['pork', 'bacon', 'pancetta', 'boar', 'sausage']
pork_df = df_recipes[df_recipes["ingredients"].str.contains('|'.join(search_values2))]
pork_df = pd.DataFrame(pork_df)
pork_df = pork_df[(pork_df["calories (number)"] <700) & (pork_df["calories (number)"] >180)&(pork_df['sugar (PDV)']<50)]
pork_df
# Out:
#                                               name  \
# 18                              chinese  chop suey
# 51                                 killer  lasagna
# 64      mr  grant you took half veal prince orloff
# 99                        the woiks  dilly burgers
# 125                                  2000 meatloaf
# ...                                            ...
# 231598             zuppa toscana from olive garden
# 231599                          zuppa toscana soup
# 231600     zuppa toscana soup   olive garden clone
# 231601          zuppa toscana soup   light version
# 231627                zwiebelwhe  swiss onion tart
#
#                                               ingredients  n_ingredients  \
# 18      ['celery', 'onion', 'ground pork', 'soy sauce'...              7
# 51      ['italian sausage', 'ground beef', 'garlic', '...             15
# 64      ['veal roast', 'butter', 'oil', 'carrots', 'on...             11
# 99      ["mccormick's montreal brand steak seasoning",...              9
# 125     ['meatloaf mixture', 'unsmoked bacon', 'goat c...             13
# ...                                                   ...            ...
# 231598  ['mild italian sausage', 'crushed red pepper f...             10
# 231599  ['chicken stock', 'light cream', 'russet potat...              7
# 231600  ['chicken stock', 'bacon', 'onion white', 'rus...             14
# 231601  ['hot italian turkey sausage', 'water', 'chick...              8
# 231627  ['flour', 'baking powder', 'kosher salt', 'uns...             13
#
#         calories (number)  total fat (PDV)  sugar (PDV)  sodium (PDV)  \
# 18                  395.4             31.0         20.0          29.0
# 51                  370.5             38.0         21.0          57.0
# 64                  510.6             50.0         10.0          21.0
# 99                  449.2             50.0         16.0          19.0
# 125                 267.0             30.0         12.0          12.0
# ...                   ...              ...          ...           ...
# 231598              531.7             59.0         13.0          74.0
# 231599              684.1             70.0         24.0          68.0
# 231600              432.8             32.0         29.0          39.0
# 231601              278.3             10.0         36.0          30.0
# 231627              440.1             49.0         15.0          10.0
#
#         protein (PDV)
# 18               51.0
# 51               53.0
# 64               90.0
# 99               58.0
# 125              29.0
# ...               ...
# 231598           38.0
# 231599           59.0
# 231600           42.0
# 231601           34.0
# 231627           22.0
#
# [12410 rows x 8 columns]

# %%
search_values3 = ['chicken', 'turkey']
chix_df = df_recipes[df_recipes["ingredients"].str.contains('|'.join(search_values3))]
chix_df = pd.DataFrame(chix_df)
chix_df = chix_df[(chix_df["calories (number)"] <700) & (chix_df["calories (number)"] >170)&(chix_df['sugar (PDV)']<50)]
chix_df
# Out:
#                                                      name  \
# 22                                crispy crunchy  chicken
# 57                   make that chicken dance  salsa pasta
# 73                                   open sesame  noodles
# 75                       pick me up  party chicken kabobs
# 85      smells like sunday  chicken fricassee with mea...
# ...                                                   ...
# 231600            zuppa toscana soup   olive garden clone
# 231601                 zuppa toscana soup   light version
# 231607              zurichgeschnetzeltes or diced chicken
# 231626              zwiebelsuppe  clear german onion soup
# 231632                                        zydeco soup
#
#                                               ingredients  n_ingredients  \
# 22      ['boneless skinless chicken breast halves', 'c...             10
# 57      ['tomatoes', 'garlic', 'onion', 'button mushro...             15
# 73      ['vermicelli', 'rice vinegar', 'reduced sodium...             12
# 75      ['boneless chicken breast', 'garlic', 'salt', ...             10
# 85      ['boneless skinless chicken thighs', 'all-purp...             15
# ...                                                   ...            ...
# 231600  ['chicken stock', 'bacon', 'onion white', 'rus...             14
# 231601  ['hot italian turkey sausage', 'water', 'chick...              8
# 231607  ['chicken breasts', 'mushrooms', 'lemon juice'...              7
# 231626  ['onions', 'red onions', 'fresh garlic', 'oliv...             11
# 231632  ['celery', 'onion', 'green sweet pepper', 'gar...             22
#
#         calories (number)  total fat (PDV)  sugar (PDV)  sodium (PDV)  \
# 22                  335.8             11.0          2.0          24.0
# 57                  255.2             18.0         39.0          18.0
# 73                  617.5             34.0         13.0          20.0
# 75                  213.6             24.0          0.0          26.0
# 85                  692.2             53.0         16.0          17.0
# ...                   ...              ...          ...           ...
# 231600              432.8             32.0         29.0          39.0
# 231601              278.3             10.0         36.0          30.0
# 231607              592.2             55.0          6.0           7.0
# 231626              252.0             17.0         21.0          44.0
# 231632              415.2             26.0         34.0          26.0
#
#         protein (PDV)
# 22               64.0
# 57               39.0
# 73               56.0
# 75               31.0
# 85              102.0
# ...               ...
# 231600           42.0
# 231601           34.0
# 231607          110.0
# 231626           21.0
# 231632           44.0
#
# [25235 rows x 8 columns]

# %%
search_values4 = ['duck', 'pheasant', 'rabbit', 'quail', 'lapin', 'goose', 'grouse']
small_game_df = df_recipes[df_recipes["ingredients"].str.contains('|'.join(search_values4))]
small_game_df = pd.DataFrame(small_game_df)
small_game_df = small_game_df[(small_game_df["calories (number)"] <700) & (small_game_df["calories (number)"] >170)&(small_game_df['sugar (PDV)']<50)]
#removed "duck sauce" from results because it was skewing data
small_game_df = small_game_df[small_game_df['ingredients'].str.contains("duck sauce")==False]
small_game_df
# Out:
#                                                      name  \
# 15786            balsamic duck breasts and asparagus pure
# 19222                             bbq duck and ramen soup
# 21358   beer braised rabbit  or chicken  for the crock...
# 21581                          belgian hare a la maryland
# 27701                                      braised rabbit
# ...                                                   ...
# 217772                                  turducken roulade
# 220110                                    upland stir fry
# 224452                 warm oriental duck and mango salad
# 224511          warm salad of duck with sesame and ginger
# 225410                          welsh rarebit with rabbit
#
#                                               ingredients  n_ingredients  \
# 15786   ['duck breasts', 'salt & pepper', 'balsamic vi...              8
# 19222   ['water', 'chicken stock', 'red chilies', 'gin...             15
# 21358   ['rabbit', 'olive oil', 'potatoes', 'carrots',...             14
# 21581   ['rabbit', 'salt and pepper', 'flour', 'eggs',...              8
# 27701   ['flour', 'salt', 'pepper', 'rabbit', 'egg', '...              8
# ...                                                   ...            ...
# 217772  ['boneless turkey breast', 'boneless duck brea...              6
# 220110  ['buttermilk baking mix', 'pepper', 'pheasant'...             11
# 224452  ['duck breasts', 'five-spice powder', 'sunflow...             13
# 224511  ['duck breasts', 'vegetable oil', 'sesame seed...             11
# 225410  ['bread', 'butter', 'extra-sharp cheddar chees...              9
#
#         calories (number)  total fat (PDV)  sugar (PDV)  sodium (PDV)  \
# 15786               671.9             45.0         29.0           9.0
# 19222               282.8             14.0         21.0          32.0
# 21358               598.9             30.0         39.0          27.0
# 21581               258.4             21.0          3.0           5.0
# 27701               412.3             34.0          7.0          33.0
# ...                   ...              ...          ...           ...
# 217772              249.6             22.0          0.0           6.0
# 220110              545.2             48.0         35.0          38.0
# 224452              314.3             22.0         46.0          19.0
# 224511              361.6             37.0         13.0           4.0
# 225410              564.2             50.0         16.0          37.0
#
#         protein (PDV)
# 15786           128.0
# 19222            21.0
# 21358           101.0
# 21581            13.0
# 27701            16.0
# ...               ...
# 217772           55.0
# 220110           67.0
# 224452           59.0
# 224511           60.0
# 225410           59.0
#
# [103 rows x 8 columns]

# %%
search_values5 = ['venison', 'deer', 'elk', 'caribou', 'moose']
big_game_df = df_recipes[df_recipes["ingredients"].str.contains('|'.join(search_values5))]
big_game_df = pd.DataFrame(big_game_df)
big_game_df = big_game_df[(big_game_df["calories (number)"] <700) & (big_game_df["calories (number)"] >170)&(big_game_df['sugar (PDV)']<50)]
big_game_df
# Out:
#                                                      name  \
# 33                               grilled  venison burgers
# 2763                           african piri   piri kabobs
# 4896                        amethyst s paleo elk meatloaf
# 12768   bacon wrapped venison tenderloin with portabel...
# 15490                       baked venison   beef parmesan
# ...                                                   ...
# 222825             venison tenderloin with cabernet sauce
# 222827                           venison tips and noodles
# 222829                    venison with plums and calvados
# 223209                        very versatile venison stew
# 227342                                wild game meatballs
#
#                                               ingredients  n_ingredients  \
# 33      ['ground venison', 'egg substitute', 'non-fat ...             10
# 2763    ['sweet potato', 'venison', 'red sweet peppers...             13
# 4896    ['ground elk', 'egg', 'carrot', 'celery', 'oni...             10
# 12768   ['venison tenderloin', 'bacon', 'yellow onion'...              9
# 15490   ['venison steak', 'fresh breadcrumb', 'parmesa...             10
# ...                                                   ...            ...
# 222825  ['venison loin', 'garlic', 'salt and black pep...             11
# 222827  ['venison stew meat', 'condensed cream of mush...              8
# 222829  ['venison tenderloins', 'olive oil', 'plums', ...             10
# 223209  ['ground venison', 'onions', 'potatoes', 'fres...              8
# 227342  ['ground elk', 'bacon', 'white onion', 'garlic...              5
#
#         calories (number)  total fat (PDV)  sugar (PDV)  sodium (PDV)  \
# 33                  190.9             10.0         10.0          10.0
# 2763                317.6             15.0         30.0          16.0
# 4896                290.6             22.0         34.0          19.0
# 12768               323.7             47.0          7.0          32.0
# 15490               458.5             30.0         30.0          35.0
# ...                   ...              ...          ...           ...
# 222825              188.2             12.0          1.0           5.0
# 222827              513.6             15.0         14.0          17.0
# 222829              245.3             15.0         39.0           0.0
# 223209              172.3              6.0         20.0          13.0
# 227342              449.8             51.0          2.0          21.0
#
#         protein (PDV)
# 33               45.0
# 2763             56.0
# 4896             54.0
# 12768            15.0
# 15490            80.0
# ...               ...
# 222825           26.0
# 222827           68.0
# 222829           50.0
# 223209           29.0
# 227342           64.0
#
# [153 rows x 8 columns]

# %%
search_values6 = ['fish', 
                  'shrimp',
                  'crab',
                  'salmon',
                  'tuna',
                  'swordfish',
                  'mackerel',
                  'bass',
                  'perch',
                  'oyster',
                  'scallop',
                  'lobster',
                  'prawn',
                  'squid',
                  'octopus',
                  'monkfish',
                  'black cod',
                  'trout',
                  'mahi-mahi', 
                  'pollock']

seafood_df = df_recipes[df_recipes["ingredients"].str.contains('|'.join(search_values6))]
seafood_df = pd.DataFrame(seafood_df)
seafood_df = seafood_df[(seafood_df["calories (number)"] <700) & (seafood_df["calories (number)"] >150)&(seafood_df['sugar (PDV)']<50)]
seafood_df
# Out:
#                                                name  \
# 78         put down your fork   tuna and bean salad
# 105                    voodoo   calamari ink  pasta
# 113     1 favorite chinese steamed whole fish by sy
# 159                                big easy   gumbo
# 163                         california roll   salad
# ...                                             ...
# 231585                               zuppa di pesce
# 231586                      zuppa di pesce castagna
# 231587       zuppa di pesce  cioppino  or fish stew
# 231619                  zwicker inn seafood chowder
# 231631                           zydeco shrimp wrap
#
#                                               ingredients  n_ingredients  \
# 78      ['light olive oil', 'red wine vinegar', 'garli...             11
# 105     ['squid', 'spaghetti', 'dry white wine', 'toma...              9
# 113     ['fish', 'scallions', 'rice wine', 'peanut oil...              9
# 159     ['vegetable oil', 'all-purpose flour', 'onion'...             12
# 163     ['white rice', 'seasoned rice vinegar', 'lettu...              8
# ...                                                   ...            ...
# 231585  ['squid', 'large shrimp', 'black pepper', 'sal...             21
# 231586  ['leeks', 'fennel bulb', 'olive oil', 'arbol c...             20
# 231587  ['olive oil', 'onions', 'garlic cloves', 'anch...             29
# 231619  ['haddock', 'lobster', 'scallops', 'butter', '...             14
# 231631  ['white rice', 'vegetable oil', 'onion', 'gree...             11
#
#         calories (number)  total fat (PDV)  sugar (PDV)  sodium (PDV)  \
# 78                  227.2             14.0          8.0          29.0
# 105                 458.1             24.0          6.0           4.0
# 113                 264.7             41.0          4.0          36.0
# 159                 484.1             42.0          7.0          32.0
# 163                 455.7             13.0         38.0          72.0
# ...                   ...              ...          ...           ...
# 231585              562.8             31.0         25.0          53.0
# 231586              392.5             29.0         11.0          43.0
# 231587              160.3              3.0         17.0          31.0
# 231619              482.7             58.0         19.0           9.0
# 231631              482.6             13.0         25.0          37.0
#
#         protein (PDV)
# 78               40.0
# 105              50.0
# 113               3.0
# 159              75.0
# 163              34.0
# ...               ...
# 231585           99.0
# 231586           68.0
# 231587           37.0
# 231619           28.0
# 231631           33.0
#
# [10228 rows x 8 columns]

# %%
all_search = (search_values+
              search_values2+
              search_values3+
              search_values4+ 
            search_values5+ 
            search_values6)

veg_other_df = df_recipes[df_recipes["ingredients"].str.contains('|'.join(all_search))==False]
veg_other_df = pd.DataFrame(veg_other_df)
veg_other_df = veg_other_df[(veg_other_df["calories (number)"] <700) & (veg_other_df["calories (number)"] >150)&(veg_other_df['sugar (PDV)']<50)]
veg_other_df
# Out:
#                                                      name  \
# 3                                      alouette  potatoes
# 6                                   aww  marinated olives
# 19                      cream  of cauliflower soup  vegan
# 25                       emotional balance  spice mixture
# 36      how i got my family to eat spinach  spinach ca...
# ...                                                   ...
# 231580                         zuppa de clams  or mussels
# 231589           zuppa di porcini  porcini mushrooms soup
# 231603                            zupse bread swiss bread
# 231622                        zwiebelbrotchen onion rolls
# 231630                                       zydeco sauce
#
#                                               ingredients  n_ingredients  \
# 3       ['spreadable cheese with garlic and herbs', 'n...             11
# 6       ['fennel seeds', 'green olives', 'ripe olives'...              9
# 19      ['canola oil', 'onion', 'garlic', 'cauliflower...             16
# 25      ['ground black pepper', 'ground ginger', 'grou...              6
# 36      ['frozen chopped spinach', 'egg', 'salt', 'bla...              8
# ...                                                   ...            ...
# 231580  ['baby clams', 'salt and pepper', 'olive oil',...              8
# 231589  ['porcini mushrooms', 'extra virgin olive oil'...              8
# 231603  ['flour', 'butter', 'milk', 'salt', 'sugar', '...              7
# 231622  ['onions', 'sesame oil', 'yeast', 'water', 'su...              9
# 231630  ['mayonnaise', 'prepared horseradish', 'worces...              6
#
#         calories (number)  total fat (PDV)  sugar (PDV)  sodium (PDV)  \
# 3                   368.1             17.0         10.0           2.0
# 6                   380.7             53.0          7.0          24.0
# 19                  174.2              4.0         24.0           1.0
# 25                  182.7             11.0          4.0           1.0
# 36                  166.1             16.0          6.0          32.0
# ...                   ...              ...          ...           ...
# 231580              358.1             56.0         21.0           0.0
# 231589              207.0             33.0          0.0           1.0
# 231603              467.4             18.0          2.0          42.0
# 231622              157.9              3.0          7.0           0.0
# 231630              239.9             30.0         19.0          22.0
#
#         protein (PDV)
# 3                14.0
# 6                 6.0
# 19               15.0
# 25               13.0
# 36               19.0
# ...               ...
# 231580            3.0
# 231589            6.0
# 231603           26.0
# 231622            8.0
# 231630            1.0
#
# [43074 rows x 8 columns]

# %%
beef_df.to_csv("df_beef.csv")
pork_df.to_csv("df_pork.csv")
chix_df.to_csv("df_chix.csv")
small_game_df.to_csv("df_small_game.csv")
big_game_df.to_csv("df_big_game.csv")
seafood_df.to_csv("df_seafood.csv")
veg_other_df.to_csv("df_veg_other.csv")
